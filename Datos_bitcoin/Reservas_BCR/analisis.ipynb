# %%
import pandas as pd #Millones de US$
import matplotlib.pyplot as plt


csv = pd.read_csv('Reservas_Internacionales_Netas_BCR.csv') #Desde 2019-01 hasta 2022-12
df = pd.DataFrame(csv)


df.drop(index=[0,1,6], axis=0, inplace=True)
df.columns = df.iloc[0]
df.drop(index=2, axis=0, inplace=True)
df = df.T
df.columns = df.iloc[0]
df.drop(index=['Concepto'],inplace=True)
df.to_csv('reservasinternacionales.csv')

# %%
csv = pd.read_csv('reservasinternacionales.csv') #dataframe ya procesado
df = pd.DataFrame(csv)

df.plot(kind='line')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
